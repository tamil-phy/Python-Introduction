# %% [markdown]
# # Reading file

# %% [markdown]
#  open(file, mode='r', buffering=- 1, encoding=None, errors=None, newline=None, closefd=True, opener=None)

# %%
file = open('example.txt','r')
content = file.read()
print(content)
# Out:
# Hi Everyone!
# Hello World! Again!
# Hello World! Again!
# Hello World! Again!

# %% [markdown]
# # Write a file

# %%
file = open('example.txt','w')

# %%
file.write("Hi Everyone!")
# Out:
# 12

# %% [markdown]
# # Appending to a file

# %%
file = open('example.txt','a')

# %%
file.write('\nHello World! Again!')
# Out:
# 20

# %%
file.close()

# %%
file = open('example.txt','r')
file.readline()
file.readline()
line = file.readline()
#while line:
print(line)
#    line = file.readline()
file.close()
# Out:
# 2

# %%
with open('example.txt','r') as file:
    line_count = 0
    for line in file:
        line_count += 1
        if line_count == 3:
            print(line)
            break
# Out:
# 2

# %%
with open('image.jpg','rb') as file:
    data = file.read()

# %%
import io
from PIL import Image

with open('image.jpg', 'rb') as file:
    data = file.read()

img = Image.open(io.BytesIO(data))
img.show()

# %%
print(data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x12\x12\x10\x10\x10\x0f\x10\x10\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x0f\x10\x0f\x0f\x0e\x0f\x0e\x15\x11\x16\x16\x15\x11\x15\x15\x18\x1d( \x18\x1a%\x1d\x15\x15!1!%)+...\x17\x1f383-7(-.+\x01\n\n\n\x0e\r\x0e\x17\x10\x10\x1a-\x1d\x1d\x1d+--+------+-----+----+----+---+-+--+---------+-+--\xff\xc0\x00\x11\x08\x00\xbe\x01\t\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x00\x05\x06\x07\x08\xff\xc4\x009\x10\x00\x02\x01\x02\x04\x04\x04\x03\x07\x03\x03\x05\x00\x00\x00\x00\x01\x02\x00\x03\x11\x04\x12!1\x05\x13AQ\x06"a\x91\x14q\x81\x072\xa1\xb1\xc1\xd1\xf0BR\xe1\x15b\xf1#$3r\x92\xff\xc4\x00\x19\x01\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\xff\xc4\x00 \x11\x01\x01\x01\x01\x00\x03\x01\x01\x01\x00\x03\x00\x00\x00\x00\x00\x00\x01\x11\x02\x03\x12!1A\x13\x042Q\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf4\xfa\x8f+\xb3A\xa9V/<\xf1\x99\xe9\xb9\xa1+J\xe5\xa1\xd30=\\\xa6\xd2\xd53)\xd2\x96\xd4\xcb\x86u\xe0\x13#4\x16h\xcd$\xc03\x0bA\x06*CQ\x1a\xa2\x02\x88b%\x18#V)L`2\xb9\xa6r\x98W\x89\r\x08\xb4\xeb\xe7\xaf\x80D\xc53Lf\x95\xea\xd4\x95\xec\xa9\x11R\xa4W2&\xadX\x83Ve\xdfM\xb9\xe5i\xea\xc0\x15%F\xad1jL\xe7\x7fZ\xe4\x8b\x99\xe0\x97\x88\xe6@5%\xfb%`\xbcK\xbcY\xa9\x13Q\xe4\xf5H\xdc\xf3/+\xa9\x8fC9\xedg\xd0\x84(j\x90\xb9q1\xa5\xdeHh|\xb8$E\xf4\x87\x9aE\xe0\x8334\xad&\xbc\xb4\xc0`\xda\x10\x9az\xb0\x15\xe3)\x18\xb1\x0c\x19\x1dEJ\xb8\x8d\x1b\xcd\x95Q\xe4\x97\x89z\xb5\xce\x90j\xcaMR(\xd6\x86\x8d_\xe6GRi\xacZ\x92\xd5\x1a\x91h\x8d\x88\x99\x12\x95!\xe6\x8fVr\x98`\xca\xe1\xa1s#\x80\xfc\xd33D\xf3 \xb3\xcd\'J\x83\xa9RQ\xadV\x15j\xb2\x8dj\xb2\xbd\x9a\xf3\x13V\xacI\xa9\x12\xf5 \xe7\x91~\xb7\x9f\x0f\xcd$4@hY\xa2\xc2\xbd\x1e\x1a\th \xc8-.3\xd1\x13\x17\xd6M\xe1 \x91\xdfxW\xa1\xd3In\x8d8\x94\x96\xe8\x89\xcb|\x9fY[\xa6"F\x84\x92\x8b\x195\xe6\xa0\x96H\x8a\xab-<\xadX\xca\xd0\xaa\